# %%
from shapely.geometry import Point
from shapely.ops import unary_union
import numpy as np
import matplotlib.pyplot as plt

# %%
a = Point(1,1).buffer(10)
b = Point(5,1).buffer(10)
un_ab = unary_union([a,b])
un_ab.boundary

# %%
extra = b.difference(a)

# %%
a = Point(1,1).buffer(10)
b = Point(5,1).buffer(10)

# %%
c = b.difference(a)

# %%
a_bound = a.boundary
c_bound = c.boundary
d = c_bound.difference(a_bound)
d

# %%
a = Point(1,1).buffer(10)
b = Point(5,1).buffer(10)
c = b.difference(a)

a_bound = a.boundary
c_bound = c.boundary.difference(a_bound)

a_coords = np.array(a_bound.coords)
c_coords = np.array(c_bound.coords)

plt.plot(a_dots[:,0], a_dots[:,1], 'ko')
plt.plot(c_dots[:,0], c_dots[:,1], 'ro')

plt.gca().set_aspect('equal')
plt.show()

# %%
c = b.difference(a).boundary.coords

for el in c:
    print(el)
# Out:
# (14.95184726672197, 0.019828596704393964)
# (14.807852804032304, -0.9509032201612824)
# (14.569403357322088, -1.9028467725446232)
# (14.238795325112868, -2.826834323650898)
# (13.819212643483551, -3.7139673682599765)
# (13.314696123025453, -4.555702330196022)
# (12.730104533627369, -5.343932841636455)
# (12.071067811865476, -6.071067811865475)
# (11.343932841636455, -6.73010453362737)
# (10.555702330196024, -7.314696123025453)
# (9.71396736825998, -7.819212643483549)
# (8.826834323650898, -8.238795325112868)
# (7.902846772544623, -8.569403357322088)
# (6.950903220161283, -8.807852804032304)
# (5.980171403295608, -8.951847266721968)
# (5.000000000000001, -9.0)
# (4.019828596704394, -8.95184726672197)
# (3.049096779838718, -8.807852804032304)
# (3.0000000000000004, -8.795554700895321)
# (3.902846772544623, -8.569403357322088)
# (4.826834323650898, -8.238795325112868)
# (5.713967368259978, -7.819212643483549)
# (6.555702330196023, -7.314696123025453)
# (7.343932841636455, -6.73010453362737)
# (8.071067811865476, -6.071067811865475)
# (8.730104533627369, -5.343932841636455)
# (9.314696123025453, -4.555702330196022)
# (9.819212643483551, -3.7139673682599765)
# (10.238795325112868, -2.826834323650898)
# (10.569403357322088, -1.9028467725446232)
# (10.807852804032304, -0.9509032201612824)
# (10.95184726672197, 0.019828596704393964)
# (11.0, 1.0)
# (10.95184726672197, 1.980171403295605)
# (10.807852804032303, 2.9509032201612873)
# (10.569403357322088, 3.902846772544625)
# (10.238795325112864, 4.826834323650904)
# (9.819212643483548, 5.71396736825998)
# (9.314696123025453, 6.555702330196022)
# (8.730104533627367, 7.343932841636459)
# (8.071067811865474, 8.071067811865477)
# (7.343932841636456, 8.730104533627369)
# (6.555702330196018, 9.314696123025454)
# (5.713967368259976, 9.819212643483551)
# (4.8268343236509, 10.238795325112866)
# (3.9028467725446205, 10.56940335732209)
# (3.0000000000000018, 10.795554700895321)
# (3.049096779838713, 10.807852804032303)
# (4.019828596704396, 10.95184726672197)
# (4.999999999999998, 11.0)
# (5.980171403295601, 10.95184726672197)
# (6.950903220161283, 10.807852804032304)
# (7.9028467725446205, 10.56940335732209)
# (8.8268343236509, 10.238795325112866)
# (9.713967368259976, 9.819212643483551)
# (10.555702330196018, 9.314696123025454)
# (11.343932841636455, 8.730104533627369)
# (12.071067811865474, 8.071067811865477)
# (12.730104533627367, 7.343932841636459)
# (13.314696123025453, 6.555702330196022)
# (13.819212643483548, 5.71396736825998)
# (14.238795325112864, 4.826834323650904)
# (14.569403357322088, 3.902846772544625)
# (14.807852804032303, 2.9509032201612873)
# (14.95184726672197, 1.980171403295605)
# (15.0, 1.0)
# (14.95184726672197, 0.019828596704393964)

# %%
a_coords = a.boundary.coords
for idx, el in enumerate(a_coords, start=1):
    print(f"{idx}. {el}")
# Out:
# 1. (11.0, 1.0)
# 2. (10.95184726672197, 0.019828596704393964)
# 3. (10.807852804032304, -0.9509032201612824)
# 4. (10.569403357322088, -1.9028467725446232)
# 5. (10.238795325112868, -2.826834323650898)
# 6. (9.819212643483551, -3.7139673682599765)
# 7. (9.314696123025453, -4.555702330196022)
# 8. (8.730104533627369, -5.343932841636455)
# 9. (8.071067811865476, -6.071067811865475)
# 10. (7.343932841636455, -6.73010453362737)
# 11. (6.555702330196023, -7.314696123025453)
# 12. (5.713967368259978, -7.819212643483549)
# 13. (4.826834323650898, -8.238795325112868)
# 14. (3.902846772544623, -8.569403357322088)
# 15. (2.9509032201612833, -8.807852804032304)
# 16. (1.9801714032956077, -8.951847266721968)
# 17. (1.0000000000000007, -9.0)
# 18. (0.01982859670439352, -8.95184726672197)
# 19. (-0.9509032201612819, -8.807852804032304)
# 20. (-1.9028467725446214, -8.56940335732209)
# 21. (-2.826834323650897, -8.238795325112868)
# 22. (-3.7139673682599774, -7.819212643483551)
# 23. (-4.55570233019602, -7.314696123025453)
# 24. (-5.3439328416364535, -6.730104533627371)
# 25. (-6.071067811865475, -6.0710678118654755)
# 26. (-6.73010453362737, -5.343932841636455)
# 27. (-7.314696123025453, -4.555702330196022)
# 28. (-7.819212643483549, -3.7139673682599783)
# 29. (-8.238795325112868, -2.826834323650899)
# 30. (-8.569403357322088, -1.902846772544624)
# 31. (-8.807852804032304, -0.9509032201612861)
# 32. (-8.951847266721968, 0.019828596704391743)
# 33. (-9.0, 0.9999999999999988)
# 34. (-8.95184726672197, 1.980171403295606)
# 35. (-8.807852804032304, 2.9509032201612837)
# 36. (-8.56940335732209, 3.902846772544621)
# 37. (-8.238795325112868, 4.826834323650896)
# 38. (-7.819212643483551, 5.7139673682599765)
# 39. (-7.314696123025454, 6.55570233019602)
# 40. (-6.730104533627371, 7.343932841636453)
# 41. (-6.071067811865477, 8.071067811865476)
# 42. (-5.343932841636458, 8.730104533627367)
# 43. (-4.555702330196022, 9.314696123025453)
# 44. (-3.713967368259979, 9.81921264348355)
# 45. (-2.8268343236509033, 10.238795325112864)
# 46. (-1.9028467725446245, 10.569403357322088)
# 47. (-0.9509032201612866, 10.807852804032303)
# 48. (0.019828596704395518, 10.95184726672197)
# 49. (0.9999999999999981, 11.0)
# 50. (1.9801714032956008, 10.95184726672197)
# 51. (2.9509032201612833, 10.807852804032304)
# 52. (3.9028467725446205, 10.56940335732209)
# 53. (4.8268343236509, 10.238795325112866)
# 54. (5.713967368259976, 9.819212643483551)
# 55. (6.555702330196018, 9.314696123025454)
# 56. (7.343932841636456, 8.730104533627369)
# 57. (8.071067811865474, 8.071067811865477)
# 58. (8.730104533627367, 7.343932841636459)
# 59. (9.314696123025453, 6.555702330196022)
# 60. (9.819212643483548, 5.71396736825998)
# 61. (10.238795325112864, 4.826834323650904)
# 62. (10.569403357322088, 3.902846772544625)
# 63. (10.807852804032303, 2.9509032201612873)
# 64. (10.95184726672197, 1.980171403295605)
# 65. (11.0, 1.0)
