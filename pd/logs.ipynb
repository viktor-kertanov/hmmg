# %%
import numpy as np

# %%
f_max = 20000
f_min = 50

# e_max = np.log(f_max)
# e_min = np.log(f_min)

# print(f'Max exponent: {e_max}')
# print(f'Min exponent: {e_min}')

# delta = e_max - e_min
# print(f'Delta: {delta}')

step = (f_max/f_min)**(1/128) - 1
# step = delta/128
print(f'Step: {step}')

for idx in range(128):
    print(f_min*(1+step)**idx)
# Out:
# Step: 0.04792112092606793
# 50.0
# 52.3960560463034
# 54.90693378414734
# 57.53813559769706
# 60.2954275515348
# 63.184852026520865
# 66.21274096117948
# 69.38572972762658
# 72.71077167244762
# 76.19515335439071
# 79.84651051226676
# 83.67284479804965
# 87.6825413118451
# 91.88438697715497
# 96.28758979670484
# 100.90179903103235
# 105.73712634405625
# 110.80416796196471
# 116.11402789398235
# 121.6783422659027
# 127.50930481971052
# 133.6196936351747
# 140.0228991319701
# 146.7329534136918
# 153.76456101806843
# 161.13313114075905
# 168.85481140335133
# 176.94652323955972
# 185.42599897716994
# 194.31182069699187
# 203.62346095397683
# 213.38132544973683
# 223.6067977499783
# 234.32228614484583
# 245.5512727548657
# 257.3183649901015
# 269.64934947529025
# 282.57124855913116
# 296.1123795315633
# 310.302416678801
# 325.172456312117
# 340.7550849128765
# 357.084450543159
# 374.19633767845625
# 392.1282456264373
# 410.9194707036287
# 430.6111923500931
# 451.2465633708202
# ...
